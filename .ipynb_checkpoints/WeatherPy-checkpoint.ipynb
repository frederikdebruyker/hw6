# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import pprint
import datetime
# import pytemperature
# not a standard library: pip install pytemperature

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
# not a standard library: pip install citipy
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# now
now = datetime.datetime.now()

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 626

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# API used: https://openweathermap.org/api

# by coordinates: api.openweathermap.org/data/2.5/weather?lat=35&lon=139
# by city name: api.openweathermap.org/data/2.5/weather?q=London

# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"

# variables
City = []
Cloudiness = []
Country = []
Date = []
Humidity = []
Lat = []
Lng = []
Max_Temp = []
Wind_Speed = []

count = 1

# query_url = url + "appid=" + api_key + "&q=" + city #to do
generic_weather_url = url + "appid=" + api_key +'&units=imperial' + "&q="
pp = pprint.PrettyPrinter(indent=4)

# functionality
print(f'\033[4m' 'Beginning Data Retrieval' '\033[0m') # status update while processing
for count, city in enumerate(cities, start=1):
#     Build query URL 
    query_url = generic_weather_url + city
#     Get weather data
    print(f'Processing Record {count} of Set 1 | {city}')
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()
    if weather_json['cod'] != 200:
        print(f'City not found. Skipping...')
    else: #include in our dataset
#         pp.pprint(weather_json)
        humidity = float(weather_json['main']['humidity'])
        if humidity <= 100:  #humidity can not be above 100 percent
            City.append(weather_json['name'])
            Cloudiness.append(weather_json['clouds']['all'])
            Country.append(weather_json['sys']['country'])
            Date.append(weather_json['dt'])
            Humidity.append(weather_json['main']['humidity'])
            Lat.append(weather_json['coord']['lat'])
            Lng.append(weather_json['coord']['lon'])
#             Max_Temp.append(pytemperature.k2f(weather_json['main']['temp_max']))
            Max_Temp.append(weather_json['main']['temp_max'])
            Wind_Speed.append(weather_json['wind']['speed'])
# Out:
# Beginning Data Retrieval
# Processing Record 1 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 1 | marystown
# Processing Record 3 of Set 1 | bathsheba
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | castro
# Processing Record 6 of Set 1 | santa cruz
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | puerto ayora
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | saint george
# Processing Record 11 of Set 1 | alihe
# Processing Record 12 of Set 1 | wetzlar
# Processing Record 13 of Set 1 | shemgang
# Processing Record 14 of Set 1 | qasigiannguit
# Processing Record 15 of Set 1 | hokitika
# Processing Record 16 of Set 1 | iqaluit
# Processing Record 17 of Set 1 | muhos
# Processing Record 18 of Set 1 | ponta do sol
# Processing Record 19 of Set 1 | sosnovskiy
# City not found. Skipping...
# Processing Record 20 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 1 | cubuk
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | wanning
# Processing Record 24 of Set 1 | sidi ali
# Processing Record 25 of Set 1 | jurado
# City not found. Skipping...
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | souillac
# Processing Record 28 of Set 1 | berlevag
# Processing Record 29 of Set 1 | saint-michel-des-saints
# Processing Record 30 of Set 1 | faanui
# Processing Record 31 of Set 1 | fortuna
# Processing Record 32 of Set 1 | sao sebastiao
# Processing Record 33 of Set 1 | mikhaylovka
# Processing Record 34 of Set 1 | atuona
# Processing Record 35 of Set 1 | vaini
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | cordoba
# Processing Record 39 of Set 1 | kismayo
# City not found. Skipping...
# Processing Record 40 of Set 1 | lorengau
# Processing Record 41 of Set 1 | barrow
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | thisted
# Processing Record 44 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 1 | ostrovnoy
# Processing Record 46 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | salalah
# Processing Record 49 of Set 1 | hangu
# Processing Record 50 of Set 1 | nemuro
# Processing Record 51 of Set 1 | sinnamary
# Processing Record 52 of Set 1 | mar del plata
# Processing Record 53 of Set 1 | iralaya
# Processing Record 54 of Set 1 | bluff
# Processing Record 55 of Set 1 | hithadhoo
# Processing Record 56 of Set 1 | kenai
# Processing Record 57 of Set 1 | victoria
# Processing Record 58 of Set 1 | mae chan
# Processing Record 59 of Set 1 | ushuaia
# Processing Record 60 of Set 1 | butaritari
# Processing Record 61 of Set 1 | mahebourg
# Processing Record 62 of Set 1 | cherskiy
# Processing Record 63 of Set 1 | balsas
# Processing Record 64 of Set 1 | itarema
# Processing Record 65 of Set 1 | isangel
# Processing Record 66 of Set 1 | east london
# Processing Record 67 of Set 1 | lavrentiya
of Set 1 | kuche
# City not found. Skipping...
# Processing Record 374 of Set 1 | guatire
# Processing Record 375 of Set 1 | moussoro
# Processing Record 376 of Set 1 | tomatlan
# Processing Record 377 of Set 1 | lakeway
# Processing Record 378 of Set 1 | taunggyi
# Processing Record 379 of Set 1 | namibe
# Processing Record 380 of Set 1 | bati
# Processing Record 381 of Set 1 | villanueva
# Processing Record 382 of Set 1 | nizwa
# Processing Record 383 of Set 1 | pokhara
# Processing Record 384 of Set 1 | koudougou
# Processing Record 385 of Set 1 | nacala
# Processing Record 386 of Set 1 | airai
# Processing Record 387 of Set 1 | nouadhibou
# Processing Record 388 of Set 1 | jacksonville
# Processing Record 389 of Set 1 | beaufort
# Processing Record 390 of Set 1 | leningradskiy
# Processing Record 391 of Set 1 | vuktyl
# Processing Record 392 of Set 1 | millet
# Processing Record 393 of Set 1 | broken hill
# Processing Record 394 of Set 1 | garm
# City not found. Skipping...
# Processing Record 395 of Set 1 | nuuk
# Processing Record 396 of Set 1 | nouakchott
# Processing Record 397 of Set 1 | aanekoski
# Processing Record 398 of Set 1 | goderich
# Processing Record 399 of Set 1 | aitape
# Processing Record 400 of Set 1 | aranos
# Processing Record 401 of Set 1 | san-pedro
# Processing Record 402 of Set 1 | lensk
# Processing Record 403 of Set 1 | buraydah
# Processing Record 404 of Set 1 | lund
# Processing Record 405 of Set 1 | magadan
# Processing Record 406 of Set 1 | akyab
# City not found. Skipping...
# Processing Record 407 of Set 1 | dhidhdhoo
# Processing Record 408 of Set 1 | bria
# Processing Record 409 of Set 1 | auki
# Processing Record 410 of Set 1 | batticaloa
# Processing Record 411 of Set 1 | longlac
# City not found. Skipping...
# Processing Record 412 of Set 1 | pangai
# Processing Record 413 of Set 1 | itabuna
# Processing Record 414 of Set 1 | leh
# Processing Record 415 of Set 1 | ayan
# Processing Record 416 of Set 1 | bambanglipuro
# Processing Record 417 of Set 1 | tunggol
# Processing Record 418 of Set 1 | high level
# Processing Record 419 of Set 1 | beyneu
# Processing Record 420 of Set 1 | butte
# Processing Record 421 of Set 1 | mocambique
# City not found. Skipping...
# Processing Record 422 of Set 1 | nacimiento
# Processing Record 423 of Set 1 | kamaishi
# Processing Record 424 of Set 1 | karratha
# Processing Record 425 of Set 1 | oistins
# Processing Record 426 of Set 1 | chapais
# Processing Record 427 of Set 1 | yialos
# City not found. Skipping...
# Processing Record 428 of Set 1 | ostersund
# Processing Record 429 of Set 1 | arrifes
# Processing Record 430 of Set 1 | tura
# Processing Record 431 of Set 1 | richards bay
# Processing Record 432 of Set 1 | honiara
# Processing Record 433 of Set 1 | bahadurgarh
# Processing Record 434 of Set 1 | aykhal
# Processing Record 435 of Set 1 | weligama
# Processing Record 436 of Set 1 | bagh
# Processing Record 437 of Set 1 | acarau
# City not found. Skipping...
# Processing Record 438 of Set 1 | abu samrah
# Processing Record 439 of Set 1 | hobyo
# Processing Record 440 of Set 1 | pangkalanbuun
# Processing Record 441 of Set 1 | dahuk
# City not found. Skipping...
# Processing Record 442 of Set 1 | kieta
# Processing Record 443 of Set 1 | gizel
# Processing Record 444 of Set 1 | korla
# City not found. Skipping...
# Processing Record 445 of Set 1 | caraballeda
# Processing Record 446 of Set 1 | sabzevar
# Processing Record 447 of Set 1 | allapalli
# Processing Record 448 of Set 1 | bukama
# Processing Record 449 of Set 1 | daltenganj
# Processing Record 450 of Set 1 | seda
# Processing Record 451 of Set 1 | srednekolymsk
# Processing Record 452 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 453 of Set 1 | qaanaaq
# Processing Record 454 of Set 1 | christchurch
# Processing Record 455 of Set 1 | miandrivazo
# Processing Record 456 of Set 1 | tual
# Processing Record 457 of Set 1 | atherton
# Processing Record 458 of Set 1 | kimbe
# Processing Record 459 of Set 1 | thanh hoa
# Processing Record 460 of Set 1 | darlowo
# Processing Record 461 of Set 1 | ancud
# Processing Record 462 of Set 1 | lincoln
# Processing Record 463 of Set 1 | pringsewu
# Processing Record 464 of Set 1 | marang
# City not found. Skipping...
# Processing Record 465 of Set 1 | ahipara
# Processing Record 466 of Set 1 | obigarm
# Processing Record 467 of Set 1 | sokoni
# Processing Record 468 of Set 1 | bara
# Processing Record 469 of Set 1 | kita
# Processing Record 470 of Set 1 | cap malheureux
# Processing Record 471 of Set 1 | yeppoon
# Processing Record 472 of Set 1 | port macquarie
# Processing Record 473 of Set 1 | goundam
# Processing Record 474 of Set 1 | bilibino
# Processing Record 475 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 476 of Set 1 | uspenka
# Processing Record 477 of Set 1 | kagadi
# Processing Record 478 of Set 1 | clyde river
# Processing Record 479 of Set 1 | zhezkazgan
# Processing Record 480 of Set 1 | kodinsk
# Processing Record 481 of Set 1 | meulaboh
# Processing Record 482 of Set 1 | bandar
# Processing Record 483 of Set 1 | araripe
# Processing Record 484 of Set 1 | mayo
# Processing Record 485 of Set 1 | port blair
# Processing Record 486 of Set 1 | san pedro
# Processing Record 487 of Set 1 | sao gabriel da cachoeira
# Processing Record 488 of Set 1 | selenginsk
# Processing Record 489 of Set 1 | truth or consequences
# Processing Record 490 of Set 1 | ust-barguzin
# Processing Record 491 of Set 1 | longyearbyen
# Processing Record 492 of Set 1 | bandar-e lengeh
# Processing Record 493 of Set 1 | biak
# Processing Record 494 of Set 1 | manitouwadge
# Processing Record 495 of Set 1 | omsukchan
# Processing Record 496 of Set 1 | poronaysk
# Processing Record 497 of Set 1 | teguldet
# Processing Record 498 of Set 1 | shimanovsk
# Processing Record 499 of Set 1 | jacareacanga
# Processing Record 500 of Set 1 | okha
# Processing Record 501 of Set 1 | boda
# Processing Record 502 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 503 of Set 1 | maues
# Processing Record 504 of Set 1 | anloga
# Processing Record 505 of Set 1 | acapulco
# Processing Record 506 of Set 1 | puerto carreno
# Processing Record 507 of Set 1 | mulanje
# Processing Record 508 of Set 1 | sovetskiy
# Processing Record 509 of Set 1 | batagay
# Processing Record 510 of Set 1 | kapit
# Processing Record 511 of Set 1 | leme
# Processing Record 512 of Set 1 | erzin
# Processing Record 513 of Set 1 | namie
# Processing Record 514 of Set 1 | genhe
# Processing Record 515 of Set 1 | roebourne
# Processing Record 516 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 517 of Set 1 | dvinskoy
# Processing Record 518 of Set 1 | pandan
# Processing Record 519 of Set 1 | eureka
# Processing Record 520 of Set 1 | tiksi
# Processing Record 521 of Set 1 | machico
# Processing Record 522 of Set 1 | baruun-urt
# Processing Record 523 of Set 1 | shakiso
# Processing Record 524 of Set 1 | tyukhtet
# Processing Record 525 of Set 1 | hargeysa
# Processing Record 526 of Set 1 | sault sainte marie
# Processing Record 527 of Set 1 | villa carlos paz
# Processing Record 528 of Set 1 | roald
# Processing Record 529 of Set 1 | buin
# Processing Record 530 of Set 1 | guane
# Processing Record 531 of Set 1 | cidreira
# Processing Record 532 of Set 1 | irbil
# City not found. Skipping...
# Processing Record 533 of Set 1 | chepo
# Processing Record 534 of Set 1 | warqla
# City not found. Skipping...
# Processing Record
of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 604 of Set 1 | ribas do rio pardo
# Processing Record 605 of Set 1 | geraldton
# Processing Record 606 of Set 1 | teacapan
# Processing Record 607 of Set 1 | chernyshevskiy
# Processing Record 608 of Set 1 | ewa beach
# Processing Record 609 of Set 1 | urumqi
# City not found. Skipping...
# Processing Record 610 of Set 1 | tocopilla
# Processing Record 611 of Set 1 | faya
# Processing Record 612 of Set 1 | ketchenery
# City not found. Skipping...
# Processing Record 613 of Set 1 | kamenka
# Processing Record 614 of Set 1 | negombo
# Processing Record 615 of Set 1 | palembang
# Processing Record 616 of Set 1 | nogliki
# Processing Record 617 of Set 1 | henties bay
# Processing Record 618 of Set 1 | garowe
# Processing Record 619 of Set 1 | port hedland
# Processing Record 620 of Set 1 | benjamin constant
# Processing Record 621 of Set 1 | kupang
# Processing Record 622 of Set 1 | lodja
# Processing Record 623 of Set 1 | kanigiri
# Processing Record 624 of Set 1 | marsa matruh
# Processing Record 625 of Set 1 | havelock
# Processing Record 626 of Set 1 | port-gentil

# %%
# build the dataframe
city_weather_dict = {
    'City':          City,
    'Cloudiness':    Cloudiness,
    'Country':       Country,
    'Date':          Date,
    'Humidity':      Humidity,
    'Lat':           Lat,
    'Lng':           Lng,
    'Max Temp':      Max_Temp,
    'Wind Speed':    Wind_Speed    
}
city_weather_data = pd.DataFrame(city_weather_dict)

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_weather_data.to_csv('WeatherPy.csv',index=False)
city_weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 557 entries, 0 to 556
# Data columns (total 9 columns):
# City          557 non-null object
# Cloudiness    557 non-null int64
# Country       557 non-null object
# Date          557 non-null int64
# Humidity      557 non-null int64
# Lat           557 non-null float64
# Lng           557 non-null float64
# Max Temp      557 non-null float64
# Wind Speed    557 non-null float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 39.2+ KB

# %%
city_weather_data.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    Marystown           8      CA  1552609280       100  47.17  -55.16
# 1    Bathsheba          20      BB  1552604400        73  13.22  -59.52
# 2  New Norfolk          20      AU  1552609639        59 -42.78  147.06
# 3       Castro           0      CL  1552604400        71 -42.48  -73.76
# 4   Santa Cruz           1      US  1552609479        39  36.97 -122.03
#
#    Max Temp  Wind Speed
# 0     -0.57        4.41
# 1     25.00        6.70
# 2     19.44        2.60
# 3     14.00        4.10
# 4     20.00        2.60

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
def generic_plot(ax_x,ax_y):
#     Build a scatter plot 
    plt.scatter(city_weather_data[ax_x], city_weather_data[ax_y], marker="o",edgecolors='black')
    x_label='Latitude'
    if ax_y == 'Max Temp':
        y_label = 'Max Temperature (F)'
        plot_title = 'City Latitude vs. Max Temperature'
    elif ax_y == 'Humidity':
        y_label= 'Humidity (%)'
        plot_title = 'City Latitude vs. Humidity'
    elif ax_y == 'Cloudiness':
        y_label= 'Cloudiness (%)'
        plot_title = 'City Latitude vs. Cloudiness'
    elif ax_y == 'Wind Speed':
        y_label= 'Wind Speed (mph)'
        plot_title = 'City Latitude vs. Cloudiness'
    else:
        y_label= 'N/A'
        plot_title = 'N/A'
   
    today=now.strftime("%m/%d/%Y")
    plot_title=plot_title+ ' ('+today+')'
    # Incorporate the other graph properties
    plt.title(plot_title)
    plt.ylabel(y_label)
    plt.xlabel(x_label)
    plt.grid(True)
    
    # Save Figure
    fig_title = (f'{plot_title}.png')
    plt.savefig('pyber ride sharing data.png')
    
    # Show plot
    plt.show()

# %%
generic_plot('Lat','Max Temp')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
generic_plot('Lat','Humidity')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
generic_plot('Lat','Cloudiness')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
generic_plot('Lat','Wind Speed')
