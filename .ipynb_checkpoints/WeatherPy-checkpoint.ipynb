# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import pprint
import datetime
import pytemperature
# not a standard library: pip install pytemperature

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
# not a standard library: pip install citipy
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# now
now = datetime.datetime.now()

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 590

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# API used: https://openweathermap.org/api

# by coordinates: api.openweathermap.org/data/2.5/weather?lat=35&lon=139
# by city name: api.openweathermap.org/data/2.5/weather?q=London

# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"

# variables
City = []
Cloudiness = []
Country = []
Date = []
Humidity = []
Lat = []
Lng = []
Max_Temp = []
Wind_Speed = []

count = 1

# query_url = url + "appid=" + api_key + "&q=" + city #to do
generic_weather_url = url + "appid=" + 'c695b8706d2f4a9452e480866f415a34' + "&q="
pp = pprint.PrettyPrinter(indent=4)

# functionality
print(f'\033[4m' 'Beginning Data Retrieval' '\033[0m') # status update while processing
for count, city in enumerate(cities, start=1):
#     Build query URL 
    query_url = generic_weather_url + city
#     Get weather data
    print(f'Processing Record {count} of Set 1 | {city}')
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()
    if weather_json['cod'] != 200:
        print(f'City not found. Skipping...')
    else: #include in our dataset
#         pp.pprint(weather_json)
        City.append(weather_json['name'])
        Cloudiness.append(weather_json['clouds']['all'])
        Country.append(weather_json['sys']['country'])
        Date.append(weather_json['dt'])
        Humidity.append(weather_json['main']['humidity'])
        Lat.append(weather_json['coord']['lat'])
        Lng.append(weather_json['coord']['lon'])
        Max_Temp.append(pytemperature.k2f(weather_json['main']['temp_max']))
        Wind_Speed.append(weather_json['wind']['speed'])
# Out:
# Beginning Data Retrieval
# Processing Record 1 of Set 1 | lebu
# Processing Record 2 of Set 1 | te anau
# Processing Record 3 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | mar del plata
# Processing Record 6 of Set 1 | avarua
# Processing Record 7 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 1 | kodiak
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | portland
# Processing Record 11 of Set 1 | ancud
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | namibe
# Processing Record 14 of Set 1 | atka
# City not found. Skipping...
# Processing Record 15 of Set 1 | port elizabeth
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | taperoa
# Processing Record 18 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 1 | qostanay
# Processing Record 22 of Set 1 | ponta delgada
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | neyvo-shaytanskiy
# Processing Record 25 of Set 1 | labuhan
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | barraute
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | galgani
# City not found. Skipping...
# Processing Record 30 of Set 1 | khatanga
# Processing Record 31 of Set 1 | cuajinicuilapa
# Processing Record 32 of Set 1 | tautira
# Processing Record 33 of Set 1 | yingcheng
# Processing Record 34 of Set 1 | mae hong son
# Processing Record 35 of Set 1 | bairiki
# City not found. Skipping...
# Processing Record 36 of Set 1 | mahebourg
# Processing Record 37 of Set 1 | naze
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | carnarvon
# Processing Record 40 of Set 1 | yar-sale
# Processing Record 41 of Set 1 | provideniya
# Processing Record 42 of Set 1 | esil
# Processing Record 43 of Set 1 | saint-philippe
# Processing Record 44 of Set 1 | torbay
# Processing Record 45 of Set 1 | nikolskoye
# Processing Record 46 of Set 1 | road town
# Processing Record 47 of Set 1 | parkes
# Processing Record 48 of Set 1 | qaanaaq
# Processing Record 49 of Set 1 | victoria
# Processing Record 50 of Set 1 | roma
# Processing Record 51 of Set 1 | kysyl-syr
# Processing Record 52 of Set 1 | new norfolk
# Processing Record 53 of Set 1 | bambous virieux
# Processing Record 54 of Set 1 | vaini
# Processing Record 55 of Set 1 | port alfred
# Processing Record 56 of Set 1 | havre-saint-pierre
# Processing Record 57 of Set 1 | hobart
# Processing Record 58 of Set 1 | punta arenas
# Processing Record 59 of Set 1 | tuktoyaktuk
# Processing Record 60 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 61 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 62 of Set 1 | atuona
# Processing Record 63 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 64 of Set 1 | tucumcari
# Processing Record 65 of Set 1 | falam
# Processing Record 66 of Set 1 | ponta do sol
# Processing Record 67 of Set 1 | longyearbyen
# Processing Record 68 of Set 1 | chuy
# Processing Record 69 of Set 1 | aklavik
# Processing Record 70 of Set 1 | yulara
# Processing Record 71 of Set 1 | saskylakh
# Processing Record 72 of Set 1 | dulce grande
# Processing Record 73 of Set 1 | bethel
# Processing Record 74 of Set 1 | yellowknife
# Processing Record 75 of Set 1 | east london
# Processing Record 221 of Set 1 | natchitoches
# Processing Record 222 of Set 1 | guerrero negro
# Processing Record 223 of Set 1 | matara
# Processing Record 224 of Set 1 | lata
# Processing Record 225 of Set 1 | goure
# Processing Record 226 of Set 1 | port lincoln
# Processing Record 227 of Set 1 | lima
# Processing Record 228 of Set 1 | san policarpo
# Processing Record 229 of Set 1 | puerto escondido
# Processing Record 230 of Set 1 | clyde river
# Processing Record 231 of Set 1 | yilan
# Processing Record 232 of Set 1 | vardo
# Processing Record 233 of Set 1 | saint anthony
# Processing Record 234 of Set 1 | punto fijo
# Processing Record 235 of Set 1 | flinders
# Processing Record 236 of Set 1 | cockburn town
# Processing Record 237 of Set 1 | kuito
# Processing Record 238 of Set 1 | yerbogachen
# Processing Record 239 of Set 1 | aswan
# Processing Record 240 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 241 of Set 1 | kattivakkam
# Processing Record 242 of Set 1 | vostok
# Processing Record 243 of Set 1 | kasangulu
# Processing Record 244 of Set 1 | bentiu
# City not found. Skipping...
# Processing Record 245 of Set 1 | troy
# Processing Record 246 of Set 1 | benjamin constant
# Processing Record 247 of Set 1 | babanusah
# City not found. Skipping...
# Processing Record 248 of Set 1 | groningen
# Processing Record 249 of Set 1 | touros
# Processing Record 250 of Set 1 | karratha
# Processing Record 251 of Set 1 | crib point
# Processing Record 252 of Set 1 | hasaki
# Processing Record 253 of Set 1 | sibolga
# Processing Record 254 of Set 1 | tuatapere
# Processing Record 255 of Set 1 | rio grande
# Processing Record 256 of Set 1 | saint-joseph
# Processing Record 257 of Set 1 | nguruka
# Processing Record 258 of Set 1 | owando
# Processing Record 259 of Set 1 | leningradskiy
# Processing Record 260 of Set 1 | grand-santi
# Processing Record 261 of Set 1 | worland
# Processing Record 262 of Set 1 | adrar
# Processing Record 263 of Set 1 | muroto
# Processing Record 264 of Set 1 | la victoria
# Processing Record 265 of Set 1 | hirara
# Processing Record 266 of Set 1 | spassk-ryazanskiy
# Processing Record 267 of Set 1 | mogadishu
# Processing Record 268 of Set 1 | tambul
# City not found. Skipping...
# Processing Record 269 of Set 1 | shache
# Processing Record 270 of Set 1 | yenagoa
# Processing Record 271 of Set 1 | kharp
# Processing Record 272 of Set 1 | kruisfontein
# Processing Record 273 of Set 1 | chimoio
# Processing Record 274 of Set 1 | jutai
# Processing Record 275 of Set 1 | basoko
# Processing Record 276 of Set 1 | lagoa
# Processing Record 277 of Set 1 | mirnyy
# Processing Record 278 of Set 1 | luganville
# Processing Record 279 of Set 1 | umm lajj
# Processing Record 280 of Set 1 | trelew
# Processing Record 281 of Set 1 | katsuura
# Processing Record 282 of Set 1 | slantsy
# Processing Record 283 of Set 1 | isangel
# Processing Record 284 of Set 1 | sola
# Processing Record 285 of Set 1 | the valley
# Processing Record 286 of Set 1 | padang
# Processing Record 287 of Set 1 | namatanai
# Processing Record 288 of Set 1 | dalby
# Processing Record 289 of Set 1 | luderitz
# Processing Record 290 of Set 1 | juegang
of Set 1 | lolua
# City not found. Skipping...
# Processing Record 437 of Set 1 | solenzo
# Processing Record 438 of Set 1 | bikaner
# Processing Record 439 of Set 1 | gat
# Processing Record 440 of Set 1 | stornoway
# City not found. Skipping...
# Processing Record 441 of Set 1 | komsomolskiy
# Processing Record 442 of Set 1 | buala
# Processing Record 443 of Set 1 | kegayli
# City not found. Skipping...
# Processing Record 444 of Set 1 | pyshma
# Processing Record 445 of Set 1 | palmer
# Processing Record 446 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 447 of Set 1 | poum
# Processing Record 448 of Set 1 | belyy yar
# Processing Record 449 of Set 1 | itarema
# Processing Record 450 of Set 1 | sidi ali
# Processing Record 451 of Set 1 | san cristobal
# Processing Record 452 of Set 1 | goba
# Processing Record 453 of Set 1 | tignere
# Processing Record 454 of Set 1 | noumea
# Processing Record 455 of Set 1 | san carlos de bariloche
# Processing Record 456 of Set 1 | rongcheng
# Processing Record 457 of Set 1 | palos heights
# Processing Record 458 of Set 1 | bafra
# City not found. Skipping...
# Processing Record 459 of Set 1 | ruatoria
# City not found. Skipping...
# Processing Record 460 of Set 1 | fergus falls
# Processing Record 461 of Set 1 | verkhnevilyuysk
# Processing Record 462 of Set 1 | anaco
# Processing Record 463 of Set 1 | pacific grove
# Processing Record 464 of Set 1 | innisfail
# Processing Record 465 of Set 1 | ayagoz
# Processing Record 466 of Set 1 | almeirim
# Processing Record 467 of Set 1 | stafford
# Processing Record 468 of Set 1 | la ronge
# Processing Record 469 of Set 1 | huescar
# Processing Record 470 of Set 1 | inirida
# Processing Record 471 of Set 1 | fort nelson
# Processing Record 472 of Set 1 | villacarrillo
# Processing Record 473 of Set 1 | magadan
# Processing Record 474 of Set 1 | batalha
# Processing Record 475 of Set 1 | kimbe
# Processing Record 476 of Set 1 | tanete
# Processing Record 477 of Set 1 | montepuez
# Processing Record 478 of Set 1 | kuala terengganu
# Processing Record 479 of Set 1 | san rafael
# Processing Record 480 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 481 of Set 1 | simpang
# Processing Record 482 of Set 1 | kalevala
# Processing Record 483 of Set 1 | balakhta
# Processing Record 484 of Set 1 | san jose
# Processing Record 485 of Set 1 | sao miguel do araguaia
# Processing Record 486 of Set 1 | deputatskiy
# Processing Record 487 of Set 1 | marrakesh
# Processing Record 488 of Set 1 | scarborough
# Processing Record 489 of Set 1 | lebanon
# Processing Record 490 of Set 1 | zhukovka
# Processing Record 491 of Set 1 | sijunjung
# Processing Record 492 of Set 1 | nenjiang
# Processing Record 493 of Set 1 | kinsale
# Processing Record 494 of Set 1 | jalu
# Processing Record 495 of Set 1 | calabozo
# Processing Record 496 of Set 1 | costache negri
# Processing Record 497 of Set 1 | havoysund
# Processing Record 498 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 499 of Set 1 | varadero
# City not found. Skipping...
# Processing Record 500 of Set 1 | san quintin
# Processing Record 501 of Set 1 | almaznyy
# Processing Record 502 of Set 1 | srednekolymsk
# Processing Record 503 of Set 1 | neyshabur
# Processing Record 504 of Set 1 | poya
# Processing Record 505 of Set 1 | assiniboia
# Processing Record 506 of Set 1 | lerwick
# Processing Record 507 of Set 1 | basco
# Processing Record 508 of Set 1 | payson
# Processing Record 509 of Set 1 | panaba
# Processing Record 510 of Set 1 | bedesa
# Processing Record 511 of Set 1 | saint-francois
# Processing Record 512 of Set 1 | sukagawa
# Processing Record 513 of Set 1 | urumqi
# City not found. Skipping...
# Processing Record 514 of Set 1 | wanning
# Processing Record 515 of Set 1 | tiznit
# Processing Record 516 of Set 1 | muzquiz
# City not found. Skipping...
# Processing Record 517 of Set 1 | santa vitoria do palmar
# Processing Record 518 of Set 1 | shingu
# Processing Record 519 of Set 1 | derzhavinsk
# Processing Record 520 of Set 1 | westpunt
# City not found. Skipping...
# Processing Record 521 of Set 1 | billings
# Processing Record 522 of Set 1 | zhezkazgan
# Processing Record 523 of Set 1 | talara
# Processing Record 524 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 525 of Set 1 | lerum
# Processing Record 526 of Set 1 | eureka
# Processing Record 527 of Set 1 | mandalgovi
# Processing Record 528 of Set 1 | goulburn
# Processing Record 529 of Set 1 | soweto
# Processing Record 530 of Set 1 | lieksa
# Processing Record 531 of Set 1 | nishihara
# Processing Record 532 of Set 1 | galiwinku
# City not found. Skipping...
# Processing Record 533 of Set 1 | maturin
# Processing Record 534 of Set 1 | rio gallegos
# Processing Record 535 of Set 1 | aykhal
# Processing Record 536 of Set 1 | hunza
# City not found. Skipping...
# Processing Record 537 of Set 1 | nhulunbuy
# Processing Record 538 of Set 1 | tinaquillo
# Processing Record 539 of Set 1 | tanout
# Processing Record 540 of Set 1 | san carlos
# Processing Record 541 of Set 1 | asau
# City not found. Skipping...
# Processing Record 542 of Set 1 | margate
# Processing Record 543 of Set 1 | abha
# Processing Record 544 of Set 1 | puri
# Processing Record 545 of Set 1 | mahajanga
# Processing Record 546 of Set 1 | broome
# Processing Record 547 of Set 1 | grand-lahou
# Processing Record 548 of Set 1 | mergui
# City not found. Skipping...
# Processing Record 549 of Set 1 | manzanillo
# Processing Record 550 of Set 1 | tocopilla
# Processing Record 551 of Set 1 | acapulco
# Processing Record 552 of Set 1 | valentin gomez farias
# Processing Record 553 of Set 1 | banapur
# Processing Record 554 of Set 1 | port moresby
# Processing Record 555 of Set 1 | chara
# Processing Record 556 of Set 1 | uglekamensk
# Processing Record 557 of Set 1 | urusha
# Processing Record 558 of Set 1 | cochrane
# Processing Record 559 of Set 1 | superior
# Processing Record 560 of Set 1 | ridgecrest
# Processing Record 561 of Set 1 | ketchikan
# Processing Record 562 of Set 1 | berdigestyakh
# Processing Record 563 of Set 1 | foumban
# Processing Record 564 of Set 1 | coihaique
# Processing Record 565 of Set 1 | jining
# Processing Record 566 of Set 1 | dombarovskiy
# Processing Record 567 of Set 1 | saint-ambroise
# Processing Record 568 of Set 1 | alice springs
# Processing Record 569 of Set 1 | verkhoturye
# Processing Record 570 of Set 1 | robinson
# Processing Record 571 of Set 1 | kharovsk
# Processing Record 572 of Set 1 | tomatlan
# Processing Record 573 of Set 1 | iwaki
# Processing Record 574 of Set 1 | hofn
# Processing Record 575 of Set 1 | hvide sande
# Processing Record 576 of Set 1 | mao
# Processing Record 577 of Set 1 | batagay-alyta
# Processing Record 578 of Set 1 | vila velha
# Processing Record 579 of Set 1 | turukhansk
# Processing Record 580 of Set 1 | uvalde
# Processing Record 581 of Set 1 | sembe
# City not found. Skipping...
# Processing Record 582 of Set 1 | nyagan
# Processing Record 583 of Set 1 | luanda
# Processing Record 584 of Set 1 | khorixas
# Processing Record 585 of Set 1 | mareeba
# Processing Record 586 of Set 1 | sao filipe
# Processing Record 587 of Set 1 | formoso do araguaia
# City not found. Skipping...
# Processing Record 588 of Set 1 | pedro ii
# Processing Record 589 of Set 1 | pesochnoye
# Processing Record 590 of Set 1 | kavieng

# %%
# build the dataframe
city_weather_dict = {
    'City':          City,
    'Cloudiness':    Cloudiness,
    'Country':       Country,
    'Date':          Date,
    'Humidity':      Humidity,
    'Lat':           Lat,
    'Lng':           Lng,
    'Max Temp':      Max_Temp,
    'Wind Speed':    Wind_Speed    
}
city_weather_data = pd.DataFrame(city_weather_dict)

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_weather_data.to_csv('WeatherPy.csv',index=False)
city_weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 530 entries, 0 to 529
# Data columns (total 9 columns):
# City          530 non-null object
# Cloudiness    530 non-null int64
# Country       530 non-null object
# Date          530 non-null int64
# Humidity      530 non-null int64
# Lat           530 non-null float64
# Lng           530 non-null float64
# Max Temp      530 non-null float64
# Wind Speed    530 non-null float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 37.3+ KB

# %%
city_weather_data.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0           Lebu          75      ET  1552514400        55   8.96   38.73
# 1        Te Anau          36      NZ  1552516323        75 -45.41  167.72
# 2     Bredasdorp          92      ZA  1552516273        93 -34.53   20.04
# 3  Mar del Plata           0      AR  1552516324        90 -46.43  -67.52
# 4         Avarua          64      CK  1552514400        74 -21.21 -159.78
#
#    Max Temp  Wind Speed
# 0     62.58        2.72
# 1     49.54        1.57
# 2     65.98        1.17
# 3     57.19        1.97
# 4     84.18        9.30

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
def generic_plot(ax_x,ax_y):
#     Build a scatter plot 
    plt.scatter(city_weather_data[ax_x], city_weather_data[ax_y], marker="o",edgecolors='black')
    x_label='Latitude'
    if ax_y == 'Max Temp':
        y_label = 'Max Temperature (F)'
        plot_title = 'City Latitude vs. Max Temperature'
    elif ax_y == 'Humidity':
        y_label= 'Humidity (%)'
        plot_title = 'City Latitude vs. Humidity'
    elif ax_y == 'Cloudiness':
        y_label= 'Cloudiness (%)'
        plot_title = 'City Latitude vs. Cloudiness'
    elif ax_y == 'Wind Speed':
        y_label= 'Wind Speed (mph)'
        plot_title = 'City Latitude vs. Cloudiness'
    else:
        y_label= 'N/A'
        plot_title = 'N/A'
   
    today=now.strftime("%m/%d/%Y")
    plot_title=plot_title+ ' ('+today+')'
    # Incorporate the other graph properties
    plt.title(plot_title)
    plt.ylabel(y_label)
    plt.xlabel(x_label)
    plt.grid(True)

# %%
generic_plot('Lat','Max Temp')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
generic_plot('Lat','Humidity')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
generic_plot('Lat','Cloudiness')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
generic_plot('Lat','Wind Speed')
